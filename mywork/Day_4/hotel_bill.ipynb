# %%
import fix 
food=int(input("What do you want? 1.Breakfast 2.Lunch 3.Dinner"))

i=0
foods=[]
quant=[]
if(food==1):
    while(i!=6):
        i=int(input("What do you prefer? 1.Idly 2.Poori 3.Pongal 4.Dosa 5.Vada 6.Enough"))
        if(i==1):
            j=int(input("How much quantity of idly you need"))
            quant.append(j)
            foods.append(i)
        elif(i==2):
            j=int(input("How much quantity of Poori you need"))
            quant.append(j)
            foods.append(i)
        elif(i==3):
            j=int(input("How much quantity of Pongal you need"))
            quant.append(j)
            foods.append(i)
        elif(i==4):
            j=int(input("How much quantity of Dosa you need"))
            quant.append(j)
            foods.append(i)
        elif(i==5):
            j=int(input("How much quantity of Vada you need"))
            quant.append(j)
            foods.append(i)
        else:
            break
if(food==2):
    while(i!=6):
        i=int(input("What do you prefer? 1.Tomato rice 2.Curd rice 3.Sambar 4.Parotta 5.Chicken 6.Enough"))
        if(i==1):
            j=int(input("How much quantity of Tomato rice you need"))
            quant.append(j)
            foods.append(i)
        elif(i==2):
            j=int(input("How much quantity of Curd rice you need"))
            quant.append(j)
            foods.append(i)
        elif(i==3):
            j=int(input("How much quantity of Sambar you need"))
            quant.append(i)
            foods.append(i)
        elif(i==4):
            j=int(input("How much quantity of Parotta you need"))
            quant.append(i)
            foods.append(i)
        elif(i==5):
            j=int(input("How much quantity of Chicken you need"))
            quant.append(i)
            foods.append(i)
        else:
            break
if(food==3):
    while(i!=6):
        i=int(input("What do you prefer? 1.Idly 2.Poori 3.Pongal 4.Dosa 5.Vada 6.Enough"))
        if(i==1):
            j=int(input("How much quantity of Idly you need"))
            quant.append(j)
            foods.append(i)
        elif(i==2):
            j=int(input("How much quantity of Poori you need"))
            quant.append(j)
            foods.append(i)
        elif(i==3):
            j=int(input("How much quantity of Pongal you need"))
            quant.append(j)
            foods.append(i)
        elif(i==4):
            j=int(input("How much quantity of Dosa you need"))
            quant.append(j)
            foods.append(i)
        elif(i==5):
            j=int(input("How much quantity of Vada you need"))
            quant.append(j)
            foods.append(i)
        else:
            break

# %%
import random 
n=random.randint(10000,99999) 
print("\t\t\t\t\t\t\t\t\t\t\tBill number:",n)
print("\t\t\t\t\t\t",fix.hotel_name)
print("\tS.I.NO\t\tFood items\t\tQuantity\t\tRate\t\tTotal")
k=0
l=1
total=0
for i in foods:
    if food==1:
        total+=quant[k]*fix.break_fast1.get(i)
        print("\t",l,"\t\t",fix.break_fast.get(i),"\t\t\t",quant[k],"\t\t\t",fix.break_fast1.get(i),"\t\t",quant[k]*fix.break_fast1.get(i))
        k=k+1
        l=l+1
    elif food==2:
        total+=quant[k]*fix.lunch1.get(i)
        print("\t",l,"\t\t",fix.lunch.get(i),"\t\t\t",quant[k],"\t\t\t",fix.lunch1.get(i),"\t\t",quant[k]*fix.lunch1.get(i))
        k=k+1
        l=l+1
    else:
        total+=quant[k]*fix.dinner1.get(i)
        print("\t",l,"\t\t",fix.dinner.get(i),"\t\t\t",quant[k],"\t\t\t",fix.dinner1.get(i),"\t\t",quant[k]*fix.dinner1.get(i))
        k=k+1
        l=l+1
print("\t\t\t\t\t\t\t\t\t\t\t\tTotal",total)
# Out:
# 											Bill number: 21935
# 						 ABCD hotel
# 	S.I.NO		Food items		Quantity		Rate		Total
# 	 1 		 Tomato rice 			 2 			 70 		 140
# 	 2 		 Parotta 			 4 			 50 		 200
# 												Total 340
